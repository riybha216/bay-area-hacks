# %%
import pandas as pd
import numpy as np

# %%
input_dir_path = '/Users/Julian/Documents/Github/BayAreaHax/Input/'

# %%
input_file_path = input_dir_path + 'County_Level_Presidential_Results_2016.csv'

# %%
election_df = pd.read_csv(input_file_path, delimiter=',', index_col=False)
election_df = election_df.drop(election_df.columns[0], axis=1)

# %%
ma_district = election_df[election_df['state_abbr'] == 'MA']
ma_district.reset_index(drop=True, inplace=True)

# %%
ma_district.rename(columns={'votes_dem':'Democratic Votes', 'votes_gop':'Republican Votes', 'total_votes':'Total Votes',
                            'per_dem':'Democratic Percentage', 'per_gop':'Republican Percentage', 'diff': 'Difference in Votes', 
                            'per_point_diff':'Difference in Percentage', 'state_abbr':'State Abbreviation', 'county_name':'County',
                            'combined_fips':'Combined FIPS'}, inplace=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
ma_district
# Out:
#     Democratic Votes  Republican Votes  Total Votes  Democratic Percentage  \
# 0            71632.0           53842.0     132667.0               0.539938
# 1            43540.0           16799.0      64507.0               0.674966
# 2           127619.0          104775.0     246068.0               0.518633
# 3             8338.0            2474.0      11434.0               0.729229
# 4           220027.0          135405.0     376140.0               0.584960
# 5            24369.0           10327.0      37987.0               0.641509
# 6           110313.0           78230.0     200220.0               0.550959
# 7            54572.0           22089.0      82329.0               0.662853
# 8           508919.0          216163.0     767337.0               0.663227
# 9             4144.0            1892.0       6404.0               0.647096
# 10          219129.0          119171.0     357781.0               0.612467
# 11          133828.0          114722.0     264168.0               0.506602
# 12          241212.0           50042.0     303517.0               0.794723
# 13          197126.0          157138.0     380972.0               0.517429
#
#     Republican Percentage Difference in Votes Difference in Percentage  \
# 0                0.405843              17,790                   13.41%
# 1                0.260421              26,741                   41.45%
# 2                0.425797              22,844                    9.28%
# 3                0.216372               5,864                   51.29%
# 4                0.359986              84,622                   22.50%
# 5                0.271856              14,042                   36.97%
# 6                0.390720              32,083                   16.02%
# 7                0.268302              32,483                   39.46%
# 8                0.281705             292,756                   38.15%
# 9                0.295440               2,252                   35.17%
# 10               0.333084              99,958                   27.94%
# 11               0.434277              19,106                    7.23%
# 12               0.164874             191,170                   62.98%
# 13               0.412466              39,988                   10.50%
#
#    State Abbreviation             County  Combined FIPS
# 0                  MA  Barnstable County          25001
# 1                  MA   Berkshire County          25003
# 2                  MA     Bristol County          25005
# 3                  MA       Dukes County          25007
# 4                  MA       Essex County          25009
# 5                  MA    Franklin County          25011
# 6                  MA     Hampden County          25013
# 7                  MA   Hampshire County          25015
# 8                  MA   Middlesex County          25017
# 9                  MA   Nantucket County          25019
# 10                 MA     Norfolk County          25021
# 11                 MA    Plymouth County          25023
# 12                 MA     Suffolk County          25025
# 13                 MA   Worcester County          25027
